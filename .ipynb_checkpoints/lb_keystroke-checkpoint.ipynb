# %% [markdown]
# ## Import

# %%
#################################
# # when running google colab # #
#################################
# from google.colab import drive
# drive.mount('/content/gdrive')
# !pip install scikeras --quiet

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import roc_curve, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

N_FEATURES = 31
TIMESTEPS = 1
DATASET_LINK = "dataset/overall.csv"
TEST_DATA_LINK = "dataset/overall_test.csv"

# random seed for reproducibility
SEED = 123

# %% [markdown]
# ### LOAD DATASET
# > * Check for class imbalance

# %%
# loading of dataset
df = pd.read_csv(DATASET_LINK)

df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t       H.t  \
# 0    Andy             1    1  0.142176     0.156880     0.014704  0.127937
# 1    Andy             1    2  0.141793     0.164635     0.022842  0.121625
# 2    Andy             1    3  0.157152     0.147220    -0.009932  0.134796
# 3    Andy             1    4  0.158673     0.142487    -0.016186  0.118908
# 4    Andy             1    5  0.166583     0.157102    -0.009480  0.115094
#
#      DD.t.i    UD.t.i       H.i  ...       H.a    DD.a.n    UD.a.n       H.n  \
# 0  0.142299  0.014361  0.155919  ...  0.128263  0.085967 -0.042296  0.120442
# 1  0.152146  0.030520  0.137039  ...  0.144490  0.082397 -0.062093  0.101188
# 2  0.145790  0.010994  0.124892  ...  0.135452  0.082423 -0.053029  0.108598
# 3  0.159179  0.040271  0.133175  ...  0.114266  0.072556 -0.041711  0.101937
# 4  0.141103  0.026009  0.135121  ...  0.125474  0.089247 -0.036227  0.114211
#
#      DD.n.l    UD.n.l       H.l  DD.l.Return  UD.l.Return  H.Return
# 0  0.209372  0.088930  0.116911     0.165437     0.048526  0.160258
# 1  0.126066  0.024878  0.098424     0.130661     0.032238  0.173819
# 2  0.155843  0.047244  0.118759     0.146550     0.027791  0.173512
# 3  0.145692  0.043755  0.096300     0.122580     0.026280  0.190808
# 4  0.149136  0.034925  0.121197     0.230113     0.108917  0.143299
#
# [5 rows x 34 columns]

# %%
#################################
# # check for class imbalance # #
#################################

sns.set_theme(style="darkgrid")
ax = sns.countplot(x="subject", data=df).set_title("Class Imbalance")

# remove missing values if available
df = df.dropna()

sns.catplot(x="subject", y="H.Return", data=df)

# %% [markdown]
# ### PREPARING DATASET
# > * Split data into X and Y
# > * Convert Y into one-hot-encoding

# %%
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,3:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

#################################
# # get all the encoded class # #
#################################
print("LabelBinarizer is able to decipher: ")
print(lb.classes_)
print("\n")

###########################
# # print X and Y shape # #
###########################
print("X dataset shape: " + str(X.shape))
print("Y dataset shape: " + str(Y.shape))
# Out:
# LabelBinarizer is able to decipher:
# ['Andy' 'Azfar' 'Chris' 'Qikai' 'Safaraz']
#
#
# X dataset shape: (500, 31)
# Y dataset shape: (500, 5)

# %% [markdown]
# ### SPLITTING DATASET
# > * Split data into train and test dataset
# > * Normalisation performed based on X_train
# > * Reshaping of dataset for LSTM Timesteps

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=SEED)


##############################################
# # normalisation and reshaping of dataset # #
##############################################
# normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# reshaping the dataset to include LSTM Timesteps
X_train = np.asarray(X_train, dtype=np.float32)
X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
X_test = np.asarray(X_test, dtype=np.float32)
X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

# retrieve number of classes
n_classes = y_train.shape[1]

print("X train shape: " + str(X_train.shape))
print("Y train shape: " + str(y_train.shape))
print("X test shape: " + str(X_test.shape))
print("Y test shape: " + str(y_test.shape))
# Out:
# X train shape: (400, 1, 31)
# Y train shape: (400, 5)
# X test shape: (100, 1, 31)
# Y test shape: (100, 5)

# %% [markdown]
# ### CREATE MODEL
# > * Create base model
# > * Wrap it with KerasClassifier

# %%
# create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=128, return_sequences=True, 
                 input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # softmax for multi-class classification
    model.add(Flatten())
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=100, 
                            batch_size=10)
    return model

# %% [markdown]
# ### INITIATE KFOLD VALIDATION
# > * evaluate best kfold validation
# > * generate loss and accuracy graph
# > * perform actual kfold validation

# %% [markdown]
# ##### evaluate suitable folds for kfold validation

# %%
# from sklearn.model_selection import LeaveOneOut
def evaluate_kfold(X_train, y_train, SEED):
    
    # evaluate the model    
    folds = range(2,11)
    means, mins, maxs = list(), list(), list()
    
    # evaluate each k value
    for k in folds:
        # define the test condition
        kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
        # evaluate k value
        model = create_model()
        scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
        k_mean = np.mean(scores)
        k_min = scores.min()
        k_max = scores.max()
        
        # report performance
        print('> folds=%d, accuracy=%.3f%% (min=%.3f%%, max=%.3f%%)' %
              (k, k_mean*100, k_min*100, k_max*100))
        
        # store mean accuracy
        means.append(k_mean)
        
        # store min and max relative to the mean
        mins.append(k_mean - k_min)
        maxs.append(k_max - k_mean)
        
    # line plot of k mean values with min/max error bars
    pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
    # show the plot
    pyplot.show()
    
evaluate_kfold(X_train, y_train, SEED)
# Out:
# > folds=2, accuracy=94.750% (min=94.500%, max=95.000%)
# > folds=3, accuracy=95.504% (min=94.030%, max=96.992%)
# > folds=4, accuracy=95.250% (min=94.000%, max=99.000%)
# > folds=5, accuracy=96.000% (min=93.750%, max=100.000%)
# > folds=6, accuracy=96.254% (min=94.030%, max=100.000%)
# > folds=7, accuracy=95.247% (min=89.474%, max=98.246%)
# > folds=8, accuracy=96.000% (min=94.000%, max=100.000%)
# > folds=9, accuracy=96.251% (min=93.182%, max=100.000%)
# > folds=10, accuracy=96.000% (min=90.000%, max=100.000%)

# %% [markdown]
# ##### generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=10, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print('Accuracy: Mean=%.3f Std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    plt.show()
    
evaluate_kfold_model(X_train, y_train, SEED)
# Out:
# Testing accuracy: 95.000%
# Testing accuracy: 100.000%
# Testing accuracy: 95.000%
# Testing accuracy: 97.500%
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C57634BE50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Testing accuracy: 90.000%
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001C57FD86790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Testing accuracy: 100.000%
# Testing accuracy: 100.000%
# Testing accuracy: 100.000%
# Testing accuracy: 92.500%
# Testing accuracy: 95.000%
# Accuracy: Mean=96.500 Std=3.391, n=10

# %% [markdown]
# ##### perform actual KFold Validation

# %%
# create model
model = create_model()

n_folds = 2
kfold = KFold(n_splits=n_folds, shuffle=True,
              random_state=SEED)

valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 3s 2ms/step - loss: 1.5082 - accuracy: 0.4650
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0557 - accuracy: 0.5900
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7985 - accuracy: 0.6850
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.7650
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6160 - accuracy: 0.7500
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5804 - accuracy: 0.7900
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8800
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4232 - accuracy: 0.8450
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8650
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4887 - accuracy: 0.8500
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3285 - accuracy: 0.8750
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3158 - accuracy: 0.8750
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4011 - accuracy: 0.8150
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2835 - accuracy: 0.9000
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3100 - accuracy: 0.8750
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3737 - accuracy: 0.8600
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4168 - accuracy: 0.8750
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.9050
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8900
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3135 - accuracy: 0.8950
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.9050
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.9050
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 0.9100
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2582 - accuracy: 0.9350
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1802 - accuracy: 0.9400
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2101 - accuracy: 0.9200
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9150
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2100 - accuracy: 0.9300
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2321 - accuracy: 0.9000
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3236 - accuracy: 0.8950
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1866 - accuracy: 0.9450
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2013 - accuracy: 0.9300
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1659 - accuracy: 0.9500
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 0.9450
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1431 - accuracy: 0.9350
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1791 - accuracy: 0.9450
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9450
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9550
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9650
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.9100
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1453 - accuracy: 0.9550
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9300
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9150
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1727 - accuracy: 0.9300
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9100
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2376 - accuracy: 0.8900
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2395 - accuracy: 0.9100
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.9000
# Epoch 49/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2734 - accuracy: 0.9000
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9250
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.9700
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1547 - accuracy: 0.9500
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9350
# Epoch 54/100
# 20/20 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.00 - 0s 2ms/step - loss: 0.1975 - accuracy: 0.9200
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9350
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9600
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 0.9400
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1376 - accuracy: 0.9400
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2192 - accuracy: 0.9200
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1504 - accuracy: 0.9500
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1711 - accuracy: 0.9500
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1683 - accuracy: 0.9300
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9250
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9550
# Epoch 65/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1902 - accuracy: 0.9500
# Epoch 66/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9600
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1393 - accuracy: 0.9500
# Epoch 68/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9750
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 0.9400
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9650
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1322 - accuracy: 0.9550
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9750
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9450
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0804 - accuracy: 0.9850
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9250
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9650
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9300
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.9550
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9450
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0907 - accuracy: 0.9650
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9650
# Epoch 82/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2600 - accuracy: 0.9100
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1211 - accuracy: 0.9450
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1538 - accuracy: 0.9400
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9200
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1379 - accuracy: 0.9650
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1998 - accuracy: 0.9450
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.9250
# Epoch 89/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9650
# Epoch 90/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1105 - accuracy: 0.9600
# Epoch 91/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1475 - accuracy: 0.9450
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1245 - accuracy: 0.9500
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9500
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9650
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.9500
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.9600
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1268 - accuracy: 0.9500
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1623 - accuracy: 0.9450
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9600
# Epoch 100/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1045 - accuracy: 0.9750
# 20/20 [==============================] - 1s 2ms/step - loss: 0.2735 - accuracy: 0.9400
# Epoch 1/100
# 20/20 [==============================] - 3s 2ms/step - loss: 1.6183 - accuracy: 0.3800
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 1.0062 - accuracy: 0.6600
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8387 - accuracy: 0.6900
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7896 - accuracy: 0.6850
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6718 - accuracy: 0.7800
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6578 - accuracy: 0.7800
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5881 - accuracy: 0.7750
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3726 - accuracy: 0.8700
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4462 - accuracy: 0.8350
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.8350
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3384 - accuracy: 0.8700
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3929 - accuracy: 0.8700
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8500
# Epoch 14/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3971 - accuracy: 0.8450
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8200
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4311 - accuracy: 0.8400
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2789 - accuracy: 0.9000
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9350
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2382 - accuracy: 0.9150
# Epoch 20/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2576 - accuracy: 0.9250
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8950
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3114 - accuracy: 0.8900
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2727 - accuracy: 0.9050
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2394 - accuracy: 0.9250
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2198 - accuracy: 0.8950
# Epoch 26/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3611 - accuracy: 0.8850
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2589 - accuracy: 0.9100
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8750
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2290 - accuracy: 0.9300
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2572 - accuracy: 0.9000
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1997 - accuracy: 0.9350
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8950
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2565 - accuracy: 0.8950
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1523 - accuracy: 0.9400
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2204 - accuracy: 0.9300
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1874 - accuracy: 0.9450
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2374 - accuracy: 0.9250
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1939 - accuracy: 0.9250
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9750
# Epoch 40/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1695 - accuracy: 0.9250
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1772 - accuracy: 0.9350
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1533 - accuracy: 0.9350
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9200
# Epoch 44/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2161 - accuracy: 0.9250
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1284 - accuracy: 0.9550
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9300
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9400
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1613 - accuracy: 0.9300
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1150 - accuracy: 0.9600
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1441 - accuracy: 0.9550
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9300
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9500
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.9300
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.9050
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1918 - accuracy: 0.9450
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9350
# Epoch 57/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9750
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0894 - accuracy: 0.9800
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9350
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 0.9500
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1330 - accuracy: 0.9500
# Epoch 62/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2147 - accuracy: 0.9200
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9550
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1403 - accuracy: 0.9650
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9450
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9400
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2320 - accuracy: 0.9250
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0997 - accuracy: 0.9750
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9550
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1375 - accuracy: 0.9550
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1778 - accuracy: 0.9250
# Epoch 72/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1293 - accuracy: 0.9550
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9850
# Epoch 74/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1185 - accuracy: 0.9550
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9650
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1247 - accuracy: 0.9500
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1188 - accuracy: 0.9550
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9600
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0973 - accuracy: 0.9750
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9400
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1548 - accuracy: 0.9450
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1624 - accuracy: 0.9550
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1079 - accuracy: 0.9600
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.9150
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9450
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9900
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9650
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1138 - accuracy: 0.9700
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1557 - accuracy: 0.9500
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1182 - accuracy: 0.9600
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1259 - accuracy: 0.9500
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.9800
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9700
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 0.9450
# Epoch 95/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1505 - accuracy: 0.9550
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9850
# Epoch 97/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.1681 - accuracy: 0.9250
# Epoch 98/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0691 - accuracy: 0.9800
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9550
# Epoch 100/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.0998 - accuracy: 0.9550
# 20/20 [==============================] - 1s 1ms/step - loss: 0.2212 - accuracy: 0.9550

# %% [markdown]
# ##### get validation accuracy

# %%
print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
# Out:
# Validation Accuracy of 94.75% (with standard deviation of 0.75%)

# %% [markdown]
# ### FIT MODEL FOR TESTING
# > * fit the model
# > * view the accuracy and loss graph
# > * view model summary

# %%
#####################
# # fit the model # #
#####################
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=1)
history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# Epoch 1/100
# 40/40 [==============================] - 5s 3ms/step - loss: 1.3261 - accuracy: 0.4850
# Epoch 2/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9263 - accuracy: 0.6350
# Epoch 3/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.7078 - accuracy: 0.7525
# Epoch 4/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5880 - accuracy: 0.7800
# Epoch 5/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.5699 - accuracy: 0.7975
# Epoch 6/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4771 - accuracy: 0.8175
# Epoch 7/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3818 - accuracy: 0.8725
# Epoch 8/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.4170 - accuracy: 0.8450
# Epoch 9/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8750
# Epoch 10/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3526 - accuracy: 0.8825
# Epoch 11/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3164 - accuracy: 0.9000
# Epoch 12/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2990 - accuracy: 0.8850
# Epoch 13/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2810 - accuracy: 0.9100
# Epoch 14/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2973 - accuracy: 0.9050
# Epoch 15/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2900 - accuracy: 0.8950
# Epoch 16/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8775
# Epoch 17/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2698 - accuracy: 0.9075
# Epoch 18/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2560 - accuracy: 0.9025
# Epoch 19/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.9050
# Epoch 20/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2193 - accuracy: 0.9100
# Epoch 21/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2903 - accuracy: 0.9075
# Epoch 22/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2430 - accuracy: 0.9000
# Epoch 23/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2416 - accuracy: 0.9125
# Epoch 24/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2879 - accuracy: 0.8975
# Epoch 25/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1947 - accuracy: 0.9350
# Epoch 26/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2632 - accuracy: 0.9125
# Epoch 27/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2120 - accuracy: 0.9225
# Epoch 28/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2649 - accuracy: 0.9125
# Epoch 29/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2249 - accuracy: 0.9200
# Epoch 30/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2019 - accuracy: 0.9350
# Epoch 31/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.9275
# Epoch 32/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2404 - accuracy: 0.9250
# Epoch 33/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2016 - accuracy: 0.9300
# Epoch 34/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2660 - accuracy: 0.9125
# Epoch 35/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1736 - accuracy: 0.9425
# Epoch 36/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1885 - accuracy: 0.9375
# Epoch 37/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9350
# Epoch 38/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1759 - accuracy: 0.9500
# Epoch 39/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2252 - accuracy: 0.9325
# Epoch 40/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1997 - accuracy: 0.9425
# Epoch 41/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1720 - accuracy: 0.9350
# Epoch 42/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2147 - accuracy: 0.9400
# Epoch 43/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1682 - accuracy: 0.9350
# Epoch 44/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9275
# Epoch 45/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1230 - accuracy: 0.9575
# Epoch 46/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1938 - accuracy: 0.9250
# Epoch 47/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1714 - accuracy: 0.9400
# Epoch 48/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1957 - accuracy: 0.9375
# Epoch 49/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 0.9425
# Epoch 50/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1721 - accuracy: 0.9425
# Epoch 51/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1726 - accuracy: 0.9425
# Epoch 52/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1260 - accuracy: 0.9425
# Epoch 53/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9600
# Epoch 54/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1460 - accuracy: 0.9475
# Epoch 55/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1792 - accuracy: 0.9375
# Epoch 56/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9250
# Epoch 57/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9350
# Epoch 58/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9425
# Epoch 59/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1464 - accuracy: 0.9450
# Epoch 60/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 0.9575
# Epoch 61/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1560 - accuracy: 0.9575
# Epoch 62/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.9500
# Epoch 63/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1783 - accuracy: 0.9425
# Epoch 64/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1385 - accuracy: 0.9500
# Epoch 65/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1270 - accuracy: 0.9525
# Epoch 66/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1277 - accuracy: 0.9550
# Epoch 67/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1550 - accuracy: 0.9475
# Epoch 68/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1465 - accuracy: 0.9500
# Epoch 69/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1360 - accuracy: 0.9475
# Epoch 70/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9650
# Epoch 71/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 0.9450
# Epoch 72/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9625
# Epoch 73/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0950 - accuracy: 0.9725
# Epoch 74/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9550
# Epoch 75/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9425
# Epoch 76/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1633 - accuracy: 0.9525
# Epoch 77/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1628 - accuracy: 0.9500
# Epoch 78/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1976 - accuracy: 0.9225
# Epoch 79/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1442 - accuracy: 0.9450
# Epoch 80/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1089 - accuracy: 0.9650
# Epoch 81/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1115 - accuracy: 0.9625
# Epoch 82/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1214 - accuracy: 0.9575
# Epoch 83/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1600 - accuracy: 0.9575
# Epoch 84/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0839 - accuracy: 0.9750
# Epoch 85/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1092 - accuracy: 0.9625
# Epoch 86/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.9650
# Epoch 87/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1189 - accuracy: 0.9525
# Epoch 88/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0895 - accuracy: 0.9675
# Epoch 89/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9575
# Epoch 90/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.9550
# Epoch 91/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0924 - accuracy: 0.9750
# Epoch 92/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1155 - accuracy: 0.9700
# Epoch 93/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1173 - accuracy: 0.9550
# Epoch 94/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0926 - accuracy: 0.9700
# Epoch 95/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9775
# Epoch 96/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1753 - accuracy: 0.9525
# Epoch 97/100
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0776 - accuracy: 0.9775
# Epoch 98/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1096 - accuracy: 0.9700
# Epoch 99/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0857 - accuracy: 0.9700
# Epoch 100/100
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9825

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
##########################
# # view model summary # #
##########################
model.model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 1, 128)            81920
#
#  dropout_36 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_36 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_37 (LSTM)              (None, 1, 128)            131584
#
#  dropout_37 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_37 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_38 (LSTM)              (None, 1, 64)             49408
#
#  dropout_38 (Dropout)        (None, 1, 64)             0
#
#  batch_normalization_38 (Bat  (None, 1, 64)            256
#  chNormalization)
#
#  flatten_12 (Flatten)        (None, 64)                0
#
#  dense_12 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 264,517
# Trainable params: 263,877
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ### MODEL TESTING
# > * get model accuracy on the test dataset
# > * generate confusion matrix
# > * generate ROC curves
# > * save the model if appropriate

# %%
y_pred = model.predict_proba(X_test)

# evaluate predictions
acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# Testing accuracy: 96.000%

# %% [markdown]
# ##### Confusion Matrix

# %%
# confusion matrix
cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                     columns = [i for i in np.unique(lb.inverse_transform(y_test))])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
# compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(n_classes):
    plt.figure()
    lw = 2
    plt.plot(
        fpr[i],
        tpr[i],
        color="darkorange",
        lw=lw,
        label="ROC curve (area = %0.2f)" % roc_auc[i],
    )
    plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Combined Plot)

# %%
# compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# first aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
# plt.figure()
# plt.plot(
#     fpr["micro"],
#     tpr["micro"],
#     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
#     color="deeppink",
#     linestyle=":",
#     linewidth=4,
# )

# plt.plot(
#     fpr["macro"],
#     tpr["macro"],
#     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
#     color="navy",
#     linestyle=":",
#     linewidth=4,
# )

colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([-0.005, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Multiclass)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### ROC Curve (Average out)

# %%
fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

# calculate equal-error-rate
eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Average ROC Curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### FIT AND SAVE MODEL
# > * fitting of model
# > * get accuracy and loss of model
# > * saving model

# %%
##############################################
# # normalisation and reshaping of dataset # #
##############################################
# loading of dataset
df = pd.read_csv(DATASET_LINK)

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,3:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

# # normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X = scaler.fit_transform(X)


# reshaping the dataset to include LSTM Timesteps
X = np.asarray(X, dtype=np.float32)
X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 3s 3ms/step - loss: 1.3075 - accuracy: 0.5080
# Epoch 2/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7291 - accuracy: 0.7160
# Epoch 3/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5988 - accuracy: 0.7860
# Epoch 4/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5193 - accuracy: 0.8100
# Epoch 5/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4051 - accuracy: 0.8600
# Epoch 6/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4657 - accuracy: 0.8320
# Epoch 7/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.8500
# Epoch 8/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3507 - accuracy: 0.8660
# Epoch 9/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3237 - accuracy: 0.8800
# Epoch 10/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3744 - accuracy: 0.8940
# Epoch 11/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2490 - accuracy: 0.9080
# Epoch 12/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3141 - accuracy: 0.8860
# Epoch 13/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8880
# Epoch 14/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2615 - accuracy: 0.9060
# Epoch 15/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2056 - accuracy: 0.9280
# Epoch 16/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1984 - accuracy: 0.9320
# Epoch 17/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1943 - accuracy: 0.9180
# Epoch 18/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3194 - accuracy: 0.8980
# Epoch 19/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2834 - accuracy: 0.8960
# Epoch 20/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.3162 - accuracy: 0.9020
# Epoch 21/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2138 - accuracy: 0.9200
# Epoch 22/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9480
# Epoch 23/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2268 - accuracy: 0.9160
# Epoch 24/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.8980
# Epoch 25/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1971 - accuracy: 0.9360
# Epoch 26/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.9300
# Epoch 27/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8820
# Epoch 28/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1967 - accuracy: 0.9220
# Epoch 29/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2172 - accuracy: 0.9260
# Epoch 30/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9540
# Epoch 31/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1889 - accuracy: 0.9440
# Epoch 32/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2281 - accuracy: 0.9080
# Epoch 33/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1784 - accuracy: 0.9360
# Epoch 34/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2323 - accuracy: 0.9120
# Epoch 35/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.9520
# Epoch 36/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1490 - accuracy: 0.9520
# Epoch 37/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.9360
# Epoch 38/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1770 - accuracy: 0.9340
# Epoch 39/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1470 - accuracy: 0.9480
# Epoch 40/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9420
# Epoch 41/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1774 - accuracy: 0.9300
# Epoch 42/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1655 - accuracy: 0.9480
# Epoch 43/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1592 - accuracy: 0.9440
# Epoch 44/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1845 - accuracy: 0.9300
# Epoch 45/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1337 - accuracy: 0.9460
# Epoch 46/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 0.9580
# Epoch 47/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9440
# Epoch 48/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.2062 - accuracy: 0.9260
# Epoch 49/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1336 - accuracy: 0.9540
# Epoch 50/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1487 - accuracy: 0.9540
# Epoch 51/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1790 - accuracy: 0.9360
# Epoch 52/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.9160
# Epoch 53/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1212 - accuracy: 0.9620
# Epoch 54/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1325 - accuracy: 0.9520
# Epoch 55/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1141 - accuracy: 0.9640
# Epoch 56/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1645 - accuracy: 0.9440
# Epoch 57/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.2111 - accuracy: 0.9340
# Epoch 58/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1658 - accuracy: 0.9520
# Epoch 59/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0877 - accuracy: 0.9780
# Epoch 60/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1988 - accuracy: 0.9400
# Epoch 61/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0956 - accuracy: 0.9720
# Epoch 62/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9620
# Epoch 63/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1841 - accuracy: 0.9500
# Epoch 64/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.9540
# Epoch 65/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1364 - accuracy: 0.9620
# Epoch 66/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9620
# Epoch 67/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9600
# Epoch 68/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.9560
# Epoch 69/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1544 - accuracy: 0.9480
# Epoch 70/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0762 - accuracy: 0.9720
# Epoch 71/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9580
# Epoch 72/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0928 - accuracy: 0.9640
# Epoch 73/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1573 - accuracy: 0.9440
# Epoch 74/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1415 - accuracy: 0.9540
# Epoch 75/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1316 - accuracy: 0.9640
# Epoch 76/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0643 - accuracy: 0.9780
# Epoch 77/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9500
# Epoch 78/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9640
# Epoch 79/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1441 - accuracy: 0.9520
# Epoch 80/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9660
# Epoch 81/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1034 - accuracy: 0.9680
# Epoch 82/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1613 - accuracy: 0.9480
# Epoch 83/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.9540
# Epoch 84/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9740
# Epoch 85/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9800
# Epoch 86/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9820
# Epoch 87/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0981 - accuracy: 0.9620
# Epoch 88/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9560
# Epoch 89/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1151 - accuracy: 0.9600
# Epoch 90/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9720
# Epoch 91/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.1189 - accuracy: 0.9540
# Epoch 92/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1137 - accuracy: 0.9660
# Epoch 93/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1200 - accuracy: 0.9640
# Epoch 94/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1225 - accuracy: 0.9480
# Epoch 95/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.9540
# Epoch 96/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9700
# Epoch 97/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.9720
# Epoch 98/100
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0740 - accuracy: 0.9740
# Epoch 99/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0648 - accuracy: 0.9800
# Epoch 100/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.0881 - accuracy: 0.9680

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ### SAVE MODEL

# %%
##################
# # save model # #
##################

model.model.save("model/key_classifier.h5")

###########################
# # save model in colab # #
###########################

# model.model.save(F"/content/gdrive/My Drive/Colab Notebooks/overall_key_classifier.h5")

# %% [markdown]
# ### LOAD MODEL

# %%
# # ##################
# # # # load model # #
# # ##################

# # model = create_model()
# model = load_model("model/key_classifier.h5")

# # ###########################
# # # # load model in colab # #
# # ###########################

# # # model.model = load_model("/content/gdrive/My Drive/Colab Notebooks/overall_key_classifier.h5")

# %% [markdown]
# ### LIVE TESTING
# > * import any new data to perform testing and prediction

# %%
# import unseen data
pred_df = pd.read_csv(TEST_DATA_LINK)
pred_df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t       H.t  \
# 0    Andy             1    1  0.174239     0.409866     0.235627  0.133840
# 1    Andy             1    2  0.145289     0.154851     0.009562  0.131217
# 2    Andy             1    3  0.122266     0.136321     0.014055  0.114905
# 3    Andy             1    4  0.121075     0.132562     0.011487  0.134813
# 4    Andy             1    5  0.141361     0.124721    -0.016640  0.098268
#
#      DD.t.i    UD.t.i       H.i  ...       H.a    DD.a.n    UD.a.n       H.n  \
# 0  0.171659  0.037820  0.156984  ...  0.137544  0.091721 -0.045824  0.099726
# 1  0.129134 -0.002083  0.130980  ...  0.164865  0.111584 -0.053281  0.101935
# 2  0.125308  0.010402  0.144332  ...  0.145501  0.095982 -0.049520  0.121049
# 3  0.132049 -0.002763  0.135681  ...  0.135072  0.089715 -0.045356  0.117885
# 4  0.149003  0.050735  0.128713  ...  0.121480  0.078897 -0.042583  0.108607
#
#      DD.n.l    UD.n.l       H.l  DD.l.Return  UD.l.Return  H.Return
# 0  0.099142 -0.000585  0.120912     0.135934     0.015022  0.163508
# 1  0.023678 -0.078258  0.140863     0.192325     0.051462  0.156958
# 2  0.091486 -0.029563  0.111422     0.145751     0.034329  0.169304
# 3  0.089209 -0.028676  0.098095     0.139069     0.040974  0.168298
# 4  0.049435 -0.059172  0.131348     0.156398     0.025050  0.170112
#
# [5 rows x 34 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[:,3:]

# print(pred_row)
############################
# # predict a single row # #
############################

pred_row=pred_df.iloc[0:1,3:]

################################
# # normalise and shape data # #
################################
pred_row = pred_row.values.tolist()
# pred_row = scaler.transform(pred_row)
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict_proba(pred_arr)
pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

pred_results = np.column_stack((pred, acc))

df = pd.DataFrame(data=pred_results, index=None, columns=['Prediction', 'Accuracy'])
print(df)
# Out:
#   Prediction   Accuracy
# 0       Andy  0.9995573
