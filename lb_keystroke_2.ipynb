# %% [markdown]
# ## Import

# %%
#################################
# # when running google colab # #
#################################
# from google.colab import drive
# drive.mount('/content/gdrive')
# !pip install scikeras --quiet

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from keras.utils.np_utils import to_categorical 
from tensorflow.keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Dense, Dropout, \
    BatchNormalization, Flatten, LSTM
# from scikeras.wrappers import KerasClassifier
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import load_model

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.preprocessing import LabelBinarizer

from sklearn.metrics import roc_curve, auc

from itertools import cycle
from scipy import interp
from scipy.optimize import brentq
from scipy.interpolate import interp1d

N_FEATURES = 31
TIMESTEPS = 1
DATASET_LINK = "https://raw.githubusercontent.com/ehandywhyy/ict3204-security-analytics/main/dataset/overall.csv?token=AE3IRTIGOZWC5ZNS5SEIR43BVEFC6"
TEST_DATA_LINK = "https://raw.githubusercontent.com/ehandywhyy/ict3204-security-analytics/main/dataset/overall_test.csv?token=AE3IRTLDOFDA673HEYDUDULBVEFD6"

# random seed for reproducibility
SEED = 10

# %% [markdown]
# ### LOAD DATASET
# > * Check for class imbalance

# %%
# loading of dataset
df = pd.read_csv(DATASET_LINK)

df.head()
# Out:
#   subject  sessionIndex  rep  ...  DD.l.Return  UD.l.Return  H.Return
# 0    Andy             1    1  ...     0.165437     0.048526  0.160258
# 1    Andy             1    2  ...     0.130661     0.032238  0.173819
# 2    Andy             1    3  ...     0.146550     0.027791  0.173512
# 3    Andy             1    4  ...     0.122580     0.026280  0.190808
# 4    Andy             1    5  ...     0.230113     0.108917  0.143299
#
# [5 rows x 34 columns]

# %%
#################################
# # check for class imbalance # #
#################################

sns.set_theme(style="darkgrid")
ax = sns.countplot(x="subject", data=df).set_title("Class Imbalance")

# remove missing values if available
df = df.dropna()

sns.catplot(x="subject", y="H.Return", data=df)

# %% [markdown]
# ### PREPARING DATASET
# > * Split data into X and Y
# > * Convert Y into one-hot-encoding

# %%
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,3:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

#################################
# # get all the encoded class # #
#################################
print("LabelBinarizer is able to decipher: ")
print(lb.classes_)
print("\n")

###########################
# # print X and Y shape # #
###########################
print("X dataset shape: " + str(X.shape))
print("Y dataset shape: " + str(Y.shape))
# Out:
# LabelBinarizer is able to decipher:
# ['Andy' 'Azfar' 'Chris' 'Qikai' 'Safaraz']
#
#
# X dataset shape: (500, 31)
# Y dataset shape: (500, 5)

# %% [markdown]
# ### SPLITTING DATASET
# > * Split data into train and test dataset
# > * Normalisation performed based on X_train
# > * Reshaping of dataset for LSTM Timesteps

# %%
##############################################################
# # split dataset into train and test set of 0.8/0.2 ratio # #
##############################################################
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=SEED)


##############################################
# # normalisation and reshaping of dataset # #
##############################################
# normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# reshaping the dataset to include LSTM Timesteps
X_train = np.asarray(X_train, dtype=np.float32)
X_train = np.reshape(X_train, (X_train.shape[0], TIMESTEPS, X_train.shape[1]))
X_test = np.asarray(X_test, dtype=np.float32)
X_test = np.reshape(X_test, (X_test.shape[0], TIMESTEPS, X_test.shape[1]))

# retrieve number of classes
n_classes = y_train.shape[1]

print("X train shape: " + str(X_train.shape))
print("Y train shape: " + str(y_train.shape))
print("X test shape: " + str(X_test.shape))
print("Y test shape: " + str(y_test.shape))
# Out:
# X train shape: (400, 1, 31)
# Y train shape: (400, 5)
# X test shape: (100, 1, 31)
# Y test shape: (100, 5)

# %% [markdown]
# ### CREATE MODEL
# > * Create base model
# > * Wrap it with KerasClassifier

# %%
# create base model
def create_base_model():
    model = Sequential()
    model.add(LSTM(units=128, return_sequences=True, 
                 input_shape=(TIMESTEPS,N_FEATURES)))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=128, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    model.add(LSTM(units=64, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())
    # softmax for multi-class classification
    model.add(Flatten())
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam',
                metrics=['accuracy'])
    return model

# wrap model in KerasClassifier
def create_model():
    model = KerasClassifier(build_fn=create_base_model, epochs=100, 
                            batch_size=50)
    return model

# %% [markdown]
# ### INITIATE KFOLD VALIDATION
# > * evaluate best kfold validation
# > * generate loss and accuracy graph
# > * perform actual kfold validation

# %% [markdown]
# ##### evaluate suitable folds for kfold validation

# %%
# # from sklearn.model_selection import LeaveOneOut
# def evaluate_kfold(X_train, y_train, SEED):
    
#     # evaluate the model    
#     folds = range(2,11)
#     means, mins, maxs = list(), list(), list()
    
#     # evaluate each k value
#     for k in folds:
#         # define the test condition
#         kfold = KFold(n_splits=k, shuffle=True, random_state=SEED)
#         # evaluate k value
#         model = create_model()
#         scores = cross_val_score(model, X_train, y_train, cv=kfold, n_jobs=-1)
        
#         k_mean = np.mean(scores)
#         k_min = scores.min()
#         k_max = scores.max()
        
#         # report performance
#         print('> folds=%d, accuracy=%.3f%% (min=%.3f%%, max=%.3f%%)' %
#               (k, k_mean*100, k_min*100, k_max*100))
        
#         # store mean accuracy
#         means.append(k_mean)
        
#         # store min and max relative to the mean
#         mins.append(k_mean - k_min)
#         maxs.append(k_max - k_mean)
        
#     # line plot of k mean values with min/max error bars
#     pyplot.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
    
#     # show the plot
#     pyplot.show()
    
# evaluate_kfold(X_train, y_train, SEED)
# Out:
# > folds=2, accuracy=94.250% (min=92.500%, max=96.000%)
# > folds=3, accuracy=95.997% (min=94.737%, max=97.015%)
# > folds=4, accuracy=95.750% (min=94.000%, max=97.000%)
# > folds=5, accuracy=96.500% (min=95.000%, max=97.500%)
# > folds=6, accuracy=94.750% (min=92.424%, max=97.015%)
# > folds=7, accuracy=95.506% (min=92.982%, max=100.000%)
# > folds=8, accuracy=96.250% (min=94.000%, max=98.000%)
# > folds=9, accuracy=96.515% (min=93.333%, max=100.000%)
# > folds=10, accuracy=96.500% (min=92.500%, max=100.000%)

# %% [markdown]
# ##### generate kfold validation accuracy and loss

# %%
##################################################
# # evaluate kfold model for accuracy and loss # #
##################################################
def evaluate_kfold_model(X_train, y_train, SEED):
    scores, histories = list(), list()
    # create model
    model = create_model()
    # prepare cross validation
    kfold = KFold(n_splits=5, shuffle=True, random_state=SEED)
    # enumerate splits
    for train_ix, test_ix in kfold.split(X_train):
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[train_ix], y_train[train_ix], X_train[test_ix], y_train[test_ix]
        # fit model
        history = model.fit(trainX, trainY, epochs=100, batch_size=50, validation_data=(testX, testY), verbose=0)
        
        # evaluate model
        y_pred = model.predict(testX)
        y_pred = to_categorical(y_pred)

        # evaluate predictions
        acc = accuracy_score(testY, y_pred)
        print("Testing accuracy: %.3f%%" % (acc*100))

        # stores scores and histories
        scores.append(acc)
        histories.append(history)

    for i in range(len(histories)):
        # plot loss
        f1 = plt.figure(1)
        plt.title('Categorical Cross-Entropy Loss')
        plt.plot(histories[i].history['loss'], color='blue')
        plt.plot(histories[i].history['val_loss'], color='orange')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        # plot accuracy
        f2 = plt.figure(2)
        plt.title('Classification Accuracy')
        plt.plot(histories[i].history['accuracy'], color='blue')
        plt.plot(histories[i].history['val_accuracy'], color='orange')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

    # print summary
    print('Accuracy: Mean=%.3f Std=%.3f, n=%d' % (np.mean(scores)*100, np.std(scores)*100, len(scores)))
    # box and whisker plots of results
    f3 = plt.figure(3)
    plt.title('Box and Whisker Plot of Accuracy Scores')
    plt.ylabel('accuracy')
    plt.xlabel('model')
    plt.boxplot(scores)
    plt.show()
    
evaluate_kfold_model(X_train, y_train, SEED)
# Out:
# Testing accuracy: 98.750%
# Testing accuracy: 96.250%
# Testing accuracy: 95.000%
# Testing accuracy: 91.250%
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff513284290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Testing accuracy: 98.750%
# Accuracy: Mean=96.000 Std=2.784, n=5

# %% [markdown]
# ##### perform actual KFold Validation

# %%
# create model
model = create_model()

n_folds = 5
kfold = KFold(n_splits=n_folds, shuffle=True,
              random_state=SEED)

valid_score = cross_val_score(model, X_train, y_train, 
                          cv=kfold, error_score="raise", verbose=0)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 6s 13ms/step - loss: 1.8645 - accuracy: 0.2875
# Epoch 2/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.1106 - accuracy: 0.5875
# Epoch 3/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.8618 - accuracy: 0.6781
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.6881 - accuracy: 0.7781
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.5737 - accuracy: 0.8094
# Epoch 6/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5021 - accuracy: 0.8531
# Epoch 7/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.4448 - accuracy: 0.8469
# Epoch 8/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3957 - accuracy: 0.8656
# Epoch 9/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3295 - accuracy: 0.8875
# Epoch 10/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0
100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0353 - accuracy: 0.9906
# Epoch 86/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0249 - accuracy: 0.9906
# Epoch 87/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0257 - accuracy: 0.9937
# Epoch 88/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0440 - accuracy: 0.9844
# Epoch 89/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0291 - accuracy: 0.9937
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0516 - accuracy: 0.9844
# Epoch 91/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0247 - accuracy: 0.9937
# Epoch 92/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0484 - accuracy: 0.9875
# Epoch 93/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 94/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0200 - accuracy: 0.9969
# Epoch 95/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0239 - accuracy: 0.9937
# Epoch 96/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 97/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0448 - accuracy: 0.9875
# Epoch 98/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0392 - accuracy: 0.9906
# Epoch 99/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0327 - accuracy: 0.9906
# Epoch 100/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0281 - accuracy: 0.9906
# WARNING:tensorflow:5 out of the last 207 calls to <function Model.make_test_function.<locals>.test_function at 0x7ff512e31680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 17ms/step - loss: 0.1877 - accuracy: 0.9500
# Epoch 1/100
# 7/7 [==============================] - 6s 16ms/step - loss: 1.5527 - accuracy: 0.4156
# Epoch 2/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.0662 - accuracy: 0.6406
# Epoch 3/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.8697 - accuracy: 0.7125
# Epoch 4/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6214 - accuracy: 0.7906
# Epoch 5/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5955 - accuracy: 0.8000
# Epoch 6/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.4261 - accuracy: 0.8500
# Epoch 7/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4203 - accuracy: 0.8562
# Epoch 8/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3907 - accuracy: 0.8938
# Epoch 9/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3555 - accuracy: 0.8875
# Epoch 10/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2704 - accuracy: 0.9187
# Epoch 11/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2438 - accuracy: 0.9344
# Epoch 12/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2485 - accuracy: 0.9344
# Epoch 13/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2202 - accuracy: 0.9250
# Epoch 14/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1833 - accuracy: 0.9531
# Epoch 15/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2132 - accuracy: 0.9438
# Epoch 16/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1946 - accuracy: 0.9469
# Epoch 17/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1564 - accuracy: 0.9469
# Epoch 18/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1539 - accuracy: 0.9500
# Epoch 19/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1663 - accuracy: 0.9563
# Epoch 20/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1604 - accuracy: 0.9500
# Epoch 21/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1561 - accuracy: 0.9531
# Epoch 22/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1260 - accuracy: 0.9719
# Epoch 23/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1427 - accuracy: 0.9625
# Epoch 24/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1527 - accuracy: 0.9500
# Epoch 25/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1385 - accuracy: 0.9594
# Epoch 26/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1269 - accuracy: 0.9625
# Epoch 27/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1217 - accuracy: 0.9625
# Epoch 28/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.1112 - accuracy: 0.9719
# Epoch 29/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0797 - accuracy: 0.9875
# Epoch 30/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1061 - accuracy: 0.9625
# Epoch 31/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1001 - accuracy: 0.9781
# Epoch 32/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0862 - accuracy: 0.9719
# Epoch 33/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0906 - accuracy: 0.9750
# Epoch 34/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0873 - accuracy: 0.9719
# Epoch 35/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0673 - accuracy: 0.9844
# Epoch 36/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0831 - accuracy: 0.9781
# Epoch 37/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0741 - accuracy: 0.9781
# Epoch 38/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0446 - accuracy: 0.9906
# Epoch 39/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0538 - accuracy: 0.9812
# Epoch 40/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0572 - accuracy: 0.9844
# Epoch 41/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0488 - accuracy: 0.9844
# Epoch 42/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0822 - accuracy: 0.9688
# Epoch 43/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.
triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 13ms/step - loss: 0.1056 - accuracy: 0.9750

# %% [markdown]
# ##### get validation accuracy

# %%
print("Validation Accuracy of %.2f%% (with standard deviation of %.2f%%)" % 
      (valid_score.mean()*100, valid_score.std()*100))
# Out:
# Validation Accuracy of 96.50% (with standard deviation of 1.46%)

# %% [markdown]
# ### FIT MODEL FOR TESTING
# > * fit the model
# > * view the accuracy and loss graph
# > * view model summary

# %%
#####################
# # fit the model # #
#####################
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=1)
history = model.fit(X_train, y_train, callbacks=es, verbose=1)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 5s 12ms/step - loss: 1.6215 - accuracy: 0.4200
# Epoch 2/100
# 8/8 [==============================] - 0s 10ms/step - loss: 1.0203 - accuracy: 0.6450
# Epoch 3/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.7637 - accuracy: 0.7250
# Epoch 4/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5669 - accuracy: 0.8350
# Epoch 5/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4854 - accuracy: 0.8375
# Epoch 6/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4579 - accuracy: 0.8625
# Epoch 7/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3621 - accuracy: 0.8875
# Epoch 8/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3296 - accuracy: 0.8925
# Epoch 9/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2864 - accuracy: 0.9150
# Epoch 10/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2441 - accuracy: 0.9250
# Epoch 11/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.2380 - accuracy: 0.9300
# Epoch 12/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2342 - accuracy: 0.9275
# Epoch 13/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1858 - accuracy: 0.9500
# Epoch 14/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.2172 - accuracy: 0.9325
# Epoch 15/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1557 - accuracy: 0.9625
# Epoch 16/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1315 - accuracy: 0.9625
# Epoch 17/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1219 - accuracy: 0.9650
# Epoch 18/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1222 - accuracy: 0.9625
# Epoch 19/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1402 - accuracy: 0.9550
# Epoch 20/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.1306 - accuracy: 0.9550
# Epoch 21/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.1323 - accuracy: 0.9600
# Epoch 22/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1140 - accuracy: 0.9650
# Epoch 23/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0961 - accuracy: 0.9750
# Epoch 24/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0941 - accuracy: 0.9850
# Epoch 25/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.1015 - accuracy: 0.9675
# Epoch 26/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0966 - accuracy: 0.9700
# Epoch 27/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0865 - accuracy: 0.9750
# Epoch 28/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0981 - accuracy: 0.9700
# Epoch 29/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0699 - accuracy: 0.9800
# Epoch 30/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0722 - accuracy: 0.9825
# Epoch 31/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0587 - accuracy: 0.9800
# Epoch 32/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0568 - accuracy: 0.9825
# Epoch 33/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0635 - accuracy: 0.9850
# Epoch 34/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0492 - accuracy: 0.9900
# Epoch 35/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0528 - accuracy: 0.9850
# Epoch 36/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0885 - accuracy: 0.9650
# Epoch 37/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0538 - accuracy: 0.9925
# Epoch 38/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0770 - accuracy: 0.9750
# Epoch 39/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0499 - accuracy: 0.9850
# Epoch 40/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0401 - accuracy: 0.9925
# Epoch 41/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0668 - accuracy: 0.9725
# Epoch 42/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0630 - accuracy: 0.9775
# Epoch 43/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0374 - accuracy: 0.9900
# Epoch 44/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9800
# Epoch 45/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0527 - accuracy: 0.9875
# Epoch 46/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0530 - accuracy: 0.9825
# Epoch 47/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0640 - accuracy: 0.9750
# Epoch 48/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0723 - accuracy: 0.9725
# Epoch 49/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0436 - accuracy: 0.9900
# Epoch 50/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0365 - accuracy: 0.9925
# Epoch 51/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0588 - accuracy: 0.9800
# Epoch 52/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0500 - accuracy: 0.9850
# Epoch 53/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0430 - accuracy: 0.9875
# Epoch 54/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0440 - accuracy: 0.9850
# Epoch 55/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0527 - accuracy: 0.9850
# Epoch 56/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0540 - accuracy: 0.9850
# Epoch 57/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0352 - accuracy: 0.9900
# Epoch 58/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0448 - accuracy: 0.9875
# Epoch 59/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0397 - accuracy: 0.9925
# Epoch 60/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0630 - accuracy: 0.9825
# Epoch 61/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0517 - accuracy: 0.9850
# Epoch 62/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0400 - accuracy: 0.9875
# Epoch 63/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0301 - accuracy: 0.9950
# Epoch 64/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0444 - accuracy: 0.9825
# Epoch 65/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0468 - accuracy: 0.9925
# Epoch 66/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0237 - accuracy: 0.9925
# Epoch 67/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0558 - accuracy: 0.9825
# Epoch 68/100
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0326 - accuracy: 0.9900
# Epoch 69/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0234 - accuracy: 0.9950
# Epoch 70/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0505 - accuracy: 0.9850
# Epoch 71/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0538 - accuracy: 0.9725
# Epoch 72/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0367 - accuracy: 0.9950
# Epoch 73/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0317 - accuracy: 0.9850
# Epoch 74/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0386 - accuracy: 0.9925
# Epoch 75/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0214 - accuracy: 0.9950
# Epoch 76/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0400 - accuracy: 0.9875
# Epoch 77/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0377 - accuracy: 0.9900
# Epoch 78/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0232 - accuracy: 0.9950
# Epoch 79/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0501 - accuracy: 0.9800
# Epoch 80/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0197 - accuracy: 0.9950
# Epoch 81/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0206 - accuracy: 0.9975
# Epoch 82/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0168 - accuracy: 0.9975
# Epoch 83/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0200 - accuracy: 0.9975
# Epoch 84/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0198 - accuracy: 0.9925
# Epoch 85/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0335 - accuracy: 0.9925
# Epoch 86/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0103 - accuracy: 0.9975
# Epoch 87/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0211 - accuracy: 0.9950
# Epoch 88/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0205 - accuracy: 0.9900
# Epoch 89/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 90/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 91/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0142 - accuracy: 0.9975
# Epoch 92/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0187 - accuracy: 0.9925
# Epoch 93/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0319 - accuracy: 0.9925
# Epoch 94/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0401 - accuracy: 0.9800
# Epoch 95/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0321 - accuracy: 0.9925
# Epoch 96/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0185 - accuracy: 0.9975
# Epoch 97/100
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0561 - accuracy: 0.9825
# Epoch 98/100
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0381 - accuracy: 0.9875
# Epoch 99/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0246 - accuracy: 0.9925
# Epoch 100/100
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0218 - accuracy: 0.9925

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
##########################
# # view model summary # #
##########################
model.model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 1, 128)            81920
#
#  dropout_30 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_30 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_31 (LSTM)              (None, 1, 128)            131584
#
#  dropout_31 (Dropout)        (None, 1, 128)            0
#
#  batch_normalization_31 (Bat  (None, 1, 128)           512
#  chNormalization)
#
#  lstm_32 (LSTM)              (None, 1, 64)             49408
#
#  dropout_32 (Dropout)        (None, 1, 64)             0
#
#  batch_normalization_32 (Bat  (None, 1, 64)            256
#  chNormalization)
#
#  flatten_10 (Flatten)        (None, 64)                0
#
#  dense_10 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 264,517
# Trainable params: 263,877
# Non-trainable params: 640
# _________________________________________________________________

# %% [markdown]
# ### MODEL TESTING
# > * get model accuracy on the test dataset
# > * generate confusion matrix
# > * generate ROC curves
# > * save the model if appropriate

# %%
y_pred = model.predict_proba(X_test)

# evaluate predictions
acc = accuracy_score(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
print("Testing accuracy: %.3f%%" % (acc*100))
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff5104aaef0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Testing accuracy: 91.000%

# %% [markdown]
# ##### Confusion Matrix

# %%
# confusion matrix
cm = confusion_matrix(lb.inverse_transform(y_test), lb.inverse_transform(y_pred))
df_cm = pd.DataFrame(cm, index = [i for i in np.unique(lb.inverse_transform(y_test))],
                     columns = [i for i in np.unique(lb.inverse_transform(y_test))])

plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=True, cmap="BuPu")

# %% [markdown]
# ##### ROC Curve (Individual)

# %%
# compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

for i in range(n_classes):
    plt.figure()
    lw = 2
    plt.plot(
        fpr[i],
        tpr[i],
        color="darkorange",
        lw=lw,
        label="ROC curve (area = %0.2f)" % roc_auc[i],
    )
    plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
    plt.xlim([-0.005, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (" + str(lb.classes_[i]) + ")")
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ##### ROC Curve (Combined Plot)

# %%
# compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], thresholds = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# first aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
# plt.figure()
# plt.plot(
#     fpr["micro"],
#     tpr["micro"],
#     label="micro-average ROC curve (area = {0:0.2f})".format(roc_auc["micro"]),
#     color="deeppink",
#     linestyle=":",
#     linewidth=4,
# )

# plt.plot(
#     fpr["macro"],
#     tpr["macro"],
#     label="macro-average ROC curve (area = {0:0.2f})".format(roc_auc["macro"]),
#     color="navy",
#     linestyle=":",
#     linewidth=4,
# )

colors = cycle(["aqua", "darkorange", "cornflowerblue", "lightgreen", "purple"])
for i, color in zip(range(n_classes), colors):
    plt.plot(
        fpr[i],
        tpr[i],
        color=color,
        lw=lw,
        label="ROC curve of class {0} (area = {1:0.2f})".format(lb.classes_[i], roc_auc[i]),
    )

plt.plot([0, 1], [0, 1], "k--", lw=lw)
plt.xlim([-0.005, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Multiclass)")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ##### ROC Curve (Average out)

# %%
fpr, tpr, threshold = roc_curve(y_test.ravel(), y_pred.ravel())

# calculate equal-error-rate
eer = brentq(lambda x : 1. - x - interp1d(fpr, tpr)(x), 0., 1.)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='AUC = {:.3f}, EER = {:.3f}'.format(auc(fpr, tpr), eer))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('Average ROC Curve')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### FIT AND SAVE MODEL
# > * fitting of model
# > * get accuracy and loss of model
# > * saving model

# %%
##############################################
# # normalisation and reshaping of dataset # #
##############################################
# loading of dataset
df = pd.read_csv("https://raw.githubusercontent.com/ehandywhyy/ict3204-security-analytics/main/dataset/overall.csv?token=AE3IRTPSRXMQ34VDOHERJTDBVEGIC")

df.head()
dataset = df.values

# divide data into features X and target (classes) Y
X = dataset[:,3:].astype(float)
Y = dataset[:,0]

# convert target Y to labelbinarizer Y for model
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

# # normalisation to 0 to 1
# scaler = MinMaxScaler(feature_range=(0, 1))
# X = scaler.fit_transform(X)


# reshaping the dataset to include LSTM Timesteps
X = np.asarray(X, dtype=np.float32)
X = np.reshape(X, (X.shape[0], TIMESTEPS, X.shape[1]))

#####################
# # fit the model # #
#####################

model = create_model()
es = EarlyStopping(monitor='loss', mode='min', min_delta=0.001, patience=50,
                   verbose=0)
history = model.fit(X, Y, callbacks=es)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 5s 11ms/step - loss: 1.5457 - accuracy: 0.3960
# Epoch 2/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.9073 - accuracy: 0.7020
# Epoch 3/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.6407 - accuracy: 0.7800
# Epoch 4/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4916 - accuracy: 0.8160
# Epoch 5/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.4430 - accuracy: 0.8580
# Epoch 6/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.4021 - accuracy: 0.8800
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.8780
# Epoch 8/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2729 - accuracy: 0.9200
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2456 - accuracy: 0.9260
# Epoch 10/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.2048 - accuracy: 0.9360
# Epoch 11/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2173 - accuracy: 0.9220
# Epoch 12/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1769 - accuracy: 0.9480
# Epoch 13/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1941 - accuracy: 0.9400
# Epoch 14/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1821 - accuracy: 0.9380
# Epoch 15/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1460 - accuracy: 0.9580
# Epoch 16/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1745 - accuracy: 0.9380
# Epoch 17/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1293 - accuracy: 0.9660
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1439 - accuracy: 0.9540
# Epoch 19/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1192 - accuracy: 0.9620
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1368 - accuracy: 0.9580
# Epoch 21/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1322 - accuracy: 0.9480
# Epoch 22/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0930 - accuracy: 0.9680
# Epoch 23/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1155 - accuracy: 0.9680
# Epoch 24/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0977 - accuracy: 0.9740
# Epoch 25/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0870 - accuracy: 0.9720
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0960 - accuracy: 0.9680
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0898 - accuracy: 0.9700
# Epoch 28/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0758 - accuracy: 0.9800
# Epoch 29/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0743 - accuracy: 0.9720
# Epoch 30/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9780
# Epoch 31/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0795 - accuracy: 0.9840
# Epoch 32/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0814 - accuracy: 0.9720
# Epoch 33/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0613 - accuracy: 0.9820
# Epoch 34/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9800
# Epoch 35/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0514 - accuracy: 0.9840
# Epoch 36/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0603 - accuracy: 0.9820
# Epoch 37/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0582 - accuracy: 0.9780
# Epoch 38/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0752 - accuracy: 0.9760
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0480 - accuracy: 0.9860
# Epoch 40/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0488 - accuracy: 0.9880
# Epoch 41/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0720 - accuracy: 0.9740
# Epoch 42/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 0.9860
# Epoch 43/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0503 - accuracy: 0.9880
# Epoch 44/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0264 - accuracy: 0.9960
# Epoch 45/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0315 - accuracy: 0.9940
# Epoch 46/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 0.9840
# Epoch 47/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0449 - accuracy: 0.9860
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0435 - accuracy: 0.9920
# Epoch 49/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0581 - accuracy: 0.9840
# Epoch 50/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0546 - accuracy: 0.9840
# Epoch 51/100
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0415 - accuracy: 0.9840
# Epoch 52/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0340 - accuracy: 0.9940
# Epoch 53/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0375 - accuracy: 0.9900
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0277 - accuracy: 0.9920
# Epoch 55/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0341 - accuracy: 0.9920
# Epoch 56/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0282 - accuracy: 0.9960
# Epoch 57/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0330 - accuracy: 0.9920
# Epoch 58/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0162 - accuracy: 0.9960
# Epoch 59/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0322 - accuracy: 0.9920
# Epoch 60/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0452 - accuracy: 0.9900
# Epoch 61/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0403 - accuracy: 0.9860
# Epoch 62/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0325 - accuracy: 0.9880
# Epoch 63/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0306 - accuracy: 0.9900
# Epoch 64/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0399 - accuracy: 0.9860
# Epoch 65/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0444 - accuracy: 0.9820
# Epoch 66/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0320 - accuracy: 0.9900
# Epoch 67/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0274 - accuracy: 0.9960
# Epoch 68/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0198 - accuracy: 0.9940
# Epoch 69/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0183 - accuracy: 0.9960
# Epoch 70/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0323 - accuracy: 0.9920
# Epoch 71/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0191 - accuracy: 0.9940
# Epoch 72/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0225 - accuracy: 0.9960
# Epoch 73/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0313 - accuracy: 0.9840
# Epoch 74/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0292 - accuracy: 0.9900
# Epoch 75/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0358 - accuracy: 0.9900
# Epoch 76/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0437 - accuracy: 0.9840
# Epoch 77/100
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0576 - accuracy: 0.9820
# Epoch 78/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0441 - accuracy: 0.9800
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0310 - accuracy: 0.9900
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0401 - accuracy: 0.9840
# Epoch 81/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0177 - accuracy: 0.9960
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0163 - accuracy: 0.9980
# Epoch 83/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0241 - accuracy: 0.9900
# Epoch 84/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0466 - accuracy: 0.9860
# Epoch 85/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0299 - accuracy: 0.9900
# Epoch 86/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0298 - accuracy: 0.9900
# Epoch 87/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0350 - accuracy: 0.9920
# Epoch 88/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0314 - accuracy: 0.9940
# Epoch 89/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0293 - accuracy: 0.9940
# Epoch 90/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0196 - accuracy: 0.9960
# Epoch 91/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0312 - accuracy: 0.9880
# Epoch 92/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0350 - accuracy: 0.9860
# Epoch 93/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0325 - accuracy: 0.9880
# Epoch 94/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0375 - accuracy: 0.9860
# Epoch 95/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0494 - accuracy: 0.9840
# Epoch 96/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0296 - accuracy: 0.9880
# Epoch 97/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0275 - accuracy: 0.9920
# Epoch 98/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0348 - accuracy: 0.9880
# Epoch 99/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0308 - accuracy: 0.9880
# Epoch 100/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0284 - accuracy: 0.9920

# %%
##########################
# # get model accuracy # #
##########################
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

######################
# # get model loss # #
######################
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# ### SAVE MODEL

# %%
##################
# # save model # #
##################

model.model.save("model/key_classifier.h5")

###########################
# # save model in colab # #
###########################

# model.model.save(F"/content/gdrive/My Drive/Colab Notebooks/overall_key_classifier.h5")

# %% [markdown]
# ### LOAD MODEL

# %%
# ##################
# # # load model # #
# ##################

# model = create_model()
model = load_model("model/key_classifier.h5")

# ###########################
# # # load model in colab # #
# ###########################

# # model.model = load_model("/content/gdrive/My Drive/Colab Notebooks/overall_key_classifier.h5")

# %% [markdown]
# ### LIVE TESTING
# > * import any new data to perform testing and prediction

# %%
# import unseen data
pred_df = pd.read_csv("https://raw.githubusercontent.com/ehandywhyy/ict3204-security-analytics/main/dataset/overall_test.csv?token=AE3IRTODWES434RKZMPQQ2TBVEGNE")
pred_df.head()
# Out:
#   subject  sessionIndex  rep  ...  DD.l.Return  UD.l.Return  H.Return
# 0    Andy             1    1  ...     0.135934     0.015022  0.163508
# 1    Andy             1    2  ...     0.192325     0.051462  0.156958
# 2    Andy             1    3  ...     0.145751     0.034329  0.169304
# 3    Andy             1    4  ...     0.139069     0.040974  0.168298
# 4    Andy             1    5  ...     0.156398     0.025050  0.170112
#
# [5 rows x 34 columns]

# %%
################################
# # check for class validity # #
################################
sns.set_theme(style="darkgrid")
ax = sns.countplot(x="subject", data=pred_df).set_title("Class Validity")

# remove missing values if available
pred_df = pred_df.dropna()

# %%
pred_dataset = pred_df.values

# # divide data into features X
# pred_row = pred_dataset[:,3:].astype(float)

#################################
# # predict more than one row # #
#################################

# pred_row=pred_df.iloc[:,3:]

############################
# # predict a single row # #
############################

pred_row=pred_df.iloc[11:12,3:]

################################
# # normalise and shape data # #
################################
pred_row = pred_row.values.tolist()
# pred_row = scaler.transform(pred_row)
pred_arr = np.asarray(pred_row, dtype=np.float32)
pred_arr = np.reshape(pred_arr, (pred_arr.shape[0], TIMESTEPS, pred_arr.shape[1]))

Y = ['Andy', 'Azfar', 'Chris', 'Qikai', 'Safaraz']
Y = np.asarray(Y)
Y = Y.reshape(-1, 1)
lb = LabelBinarizer().fit(Y)
Y = lb.transform(Y)

# %%
####################################
# # get prediction and its label # #
####################################

pred_proba = model.predict(pred_arr)
pred = lb.inverse_transform(pred_proba)
acc = np.max(pred_proba, axis=1)

pred_results = np.column_stack((pred, acc))

df = pd.DataFrame(data=pred_results, index=None, columns=['Prediction', 'Accuracy'])
print(df)
# Out:
#   Prediction    Accuracy
# 0      Chris  0.98488855
